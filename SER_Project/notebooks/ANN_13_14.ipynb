# %% [markdown]
# # Week 13/14: ANN
# ## Project Tasks:
# - Implement a simple ANN from scratch in MiniLearn
# - Apply one off-the-shelf DL model (e.g., Dense NN, 1D-CNN, or LSTM)
# - Compare with classical models
# - Finalize report and clean repository

# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append("..")

from minilearn import StandardScaler, train_test_split
from minilearn import ANNClassifier
from minilearn import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression as SKLogisticRegression

# %%
fpath = os.path.join("../data", "week5_audio.csv")

feature_df = pd.read_csv(fpath)

feature_df.head()
# Out:
#    mfcc_1_mean  mfcc_1_std  mfcc_1_min  mfcc_1_max  mfcc_2_mean  mfcc_2_std  \
# 0   -726.21720   157.85083  -861.53260  -432.15480     68.54142   84.219345
# 1   -719.12830   159.35600  -861.44400  -417.70416     70.20157   78.612820
# 2   -714.99570   162.87424  -851.23380  -412.74353     69.68935   85.796005
# 3   -710.97530   161.77583  -847.86710  -388.34793     67.56488   78.593960
# 4   -759.92175   162.98659  -917.40265  -454.39650     75.78352   78.566280
#
#    mfcc_2_min  mfcc_2_max  mfcc_3_mean  mfcc_3_std  ...  spectral_rolloff_std  \
# 0  -85.970474   236.70389     3.293398   20.393255  ...           7873.634242
# 1  -14.972853   218.36372     1.168397   23.063353  ...           7634.107567
# 2  -45.141598   229.02920     3.924564   17.979307  ...           7981.393363
# 3  -37.103306   216.24066     5.782241   20.279503  ...           7570.671093
# 4  -18.632597   230.43222     6.023605   23.161620  ...           7902.073642
#
# ...

# %%
m_cols = ["path", "filename", "emotion", "intensity", "actor", "gender", "vocal_channel"]
f_cols = []

for c in feature_df.columns:
    if c not in m_cols:
        f_cols.append(c)

X = feature_df[f_cols]
y = feature_df["emotion"]

# %%
# Splits into train, validation, test
X_train_full, X_test, y_train_full, y_test = train_test_split(X,y,test_size=0.2,stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train_full,y_train_full,test_size=0.25,stratify=y_train_full)

X_train_full = np.array(X_train_full, dtype=float)
X_test = np.array(X_test, dtype=float)
X_train = np.array(X_train, dtype=float)
X_val = np.array(X_val, dtype=float)
y_train_full = np.array(y_train_full)
y_test = np.array(y_test)
y_train = np.array(y_train)
y_val = np.array(y_val)

scaler1 = StandardScaler()
X_train_scale = scaler1.fit_transform(X_train)
X_val_scale = scaler1.transform(X_val)

scaler2 = StandardScaler()
X_train_full_scale = scaler2.fit_transform(X_train_full)
X_test_scale = scaler2.transform(X_test)

# %%
mini_ann = ANNClassifier(hidden_size=24, learning_rate=0.03, n_iter=300, random_state=123)
mini_ann.fit(X_train_scale, y_train)
mini_val_pred = mini_ann.predict(X_val_scale)

print("ML ANN validation accuracy: ", accuracy_score(y_val, mini_val_pred))

plt.figure(figsize=(10,5))
plt.plot(mini_ann.loss_)
plt.title("ML ANN Training Loss")
plt.xlabel("Iteration")
plt.ylabel("Cross Entropy Loss")
# Out:
# ML ANN validation accuracy:  0.5807770961145194
# Text(0, 0.5, 'Cross Entropy Loss')

# %%
# Trains the final models on training set

mini_ann_final = ANNClassifier(hidden_size=24, learning_rate=0.03, n_iter=300, random_state=123)
mini_ann_final.fit(X_train_full_scale, y_train_full)
mini_pred = mini_ann_final.predict(X_test_scale)

sk_ann = MLPClassifier(hidden_layer_sizes=(64, 32), activation="relu", solver="adam", alpha=0.001, learning_rate_init=0.001, max_iter=300, random_state=123)
sk_ann.fit(X_train_full_scale, y_train_full)
sk_pred = sk_ann.predict(X_test_scale)

classic_lr = SKLogisticRegression(max_iter=5000)
classic_lr.fit(X_train_full_scale, y_train_full)
lr_pred = classic_lr.predict(X_test_scale)

# %%
results = []

results.append({"model": "MiniLearn ANN", "parameters": "hidden_size=24, lr=0.03, n_iter=300", "accuracy": accuracy_score(y_test, mini_pred), "weighted_precision": precision_score(y_test, mini_pred, avg="weighted"), "weighted_recall": recall_score(y_test, mini_pred, avg="weighted"), "weighted_F1": f1_score(y_test, mini_pred, avg="weighted")})

results.append({"model": "sklearn Dense NN", "parameters": "hidden=(64,32), adam", "accuracy": accuracy_score(y_test, sk_pred), "weighted_precision": precision_score(y_test, sk_pred, avg="weighted"), "weighted_recall": recall_score(y_test, sk_pred, avg="weighted"), "weighted_F1": f1_score(y_test, sk_pred, avg="weighted")})

results.append({"model": "sklearn Logistic Regression", "parameters": "max_iter=5000", "accuracy": accuracy_score(y_test, lr_pred), "weighted_precision": precision_score(y_test, lr_pred, avg="weighted"), "weighted_recall": recall_score(y_test, lr_pred, avg="weighted"), "weighted_F1": f1_score(y_test, lr_pred, avg="weighted")})

ann_results_df = pd.DataFrame(results)
ann_results_df = ann_results_df.sort_values("weighted_F1", ascending=False)

ann_results_df
# Out:
#                          model                           parameters  accuracy  \
# 1             sklearn Dense NN                 hidden=(64,32), adam  0.687117
# 2  sklearn Logistic Regression                        max_iter=5000  0.674847
# 0                MiniLearn ANN  hidden_size=24, lr=0.03, n_iter=300  0.595092
#
#    weighted_precision  weighted_recall  weighted_F1
# 1            0.688440         0.687117     0.686459
# 2            0.676446         0.674847     0.673312
# 0            0.594259         0.595092     0.588501

# %%
preds = {"MiniLearn ANN": mini_pred, "sklearn Dense NN": sk_pred, "sklearn Logistic Regression": lr_pred}

best_model = ann_results_df.iloc[0]["model"]
best_pred = preds[best_model]
labels = np.unique(y_test)
cmatrix = confusion_matrix(y_test, best_pred, labels=labels)

plt.figure(figsize=(10,5))
sns.heatmap(cmatrix, annot=True, fmt="d", xticklabels=labels, yticklabels=labels, cmap="Blues")
plt.title("Confusion Matrix - " + best_model)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(95.72222222222221, 0.5, 'Actual')

# %%
plt.figure(figsize=(10,5))
plt.plot(sk_ann.loss_curve_)
plt.title("SKlearn DenseNN Training Loss")
plt.xlabel("Iteration")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
