# %% [markdown]
# # Week 8: SVM
# ## Project Tasks:
# - Apply SVM with linear, RBF, and polynomial kernels
# - Tune hyperparameters (C, gamma)

# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import sys
sys.path.append("..")

from
